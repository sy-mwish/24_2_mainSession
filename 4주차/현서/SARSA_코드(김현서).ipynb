# %% [markdown]
# # Import : by GitHub

# %% [markdown]
# You can try this code in Colab by this method.

# %%
# !git clone https://github.com/KanghwaSisters/24_2_mainSession.git
# Out:
# Cloning into '24_2_mainSession'...
# remote: Enumerating objects: 225, done.
# remote: Counting objects: 100% (77/77), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 225 (delta 50), reused 50 (delta 34), pack-reused 148 (from 1)
# Receiving objects: 100% (225/225), 1.17 MiB | 5.41 MiB/s, done.
# Resolving deltas: 100% (92/92), done.

# %%
import os
os.chdir('/content/24_2_mainSession/4주차/env')

# %%
! python GridWorldEnvironment.py

# %%
from GridWorldEnvironment import GridWorldEnvironment

# %%
env = GridWorldEnvironment(start_point=(0,0),
                           end_point=(4,4),
                           gridworld_size=(5,5))

# %% [markdown]
# # SARSA Class

# %%
import numpy as np
import random

class SarsaAgent:
    def __init__(self, env, alpha=0.1, gamma=0.99, epsilon=0.1):
        self.env = env
        self.alpha = alpha  # 학습률
        self.gamma = gamma  # 할인률
        self.epsilon = epsilon  # 탐험률

        # Q테이블
        self.q_table = np.zeros((env.height, env.width, env.num_actions))

    #주어진 상태에서 어떤 행동을 선택할지 결정하는 함수, 탐험(Explore): 새로운 행동을 랜덤하게 시도하여, 미지의 정보를 찾는 과정 / 이용(Exploit): 이전에 학습한 정보(Q-값)를 기반으로, 최적의 행동을 선택하는 과정.
    def choose_action(self, state):
        if random.uniform(0, 1) < self.epsilon: # epsilon이 0.1이라면, 에이전트가 10% 확률로 탐험, 90% 확률로 이용
            return random.randint(0, self.env.num_actions - 1)  # Explore : 탐험 / 무작위로 행동을 선택하는 과정
        else:
            row_diff, col_diff, _ = state
            return np.argmax(self.q_table[row_diff, col_diff])  # Exploit : 아는 값 활용 / 주어진 배열에서 가장 큰 값의 인덱스를 반환하여 현재 상태에서 가장 높은 Q-값을 가진 행동을 선택하는 과정.

    #SARSA 알고리즘의 핵심인 Q-값을 업데이트하는 함수
    def update_q_table(self, state, action, reward, next_state, next_action):
        row_diff, col_diff, _ = state
        next_row_diff, next_col_diff, _ = next_state  #state와 next_state는 각각 현재와 다음 상태의 정보,그리드월드에서 에이전트가 목표지점과 얼마나 떨어져 있는지를 나타냄

        # SARSA 업데이트 규칙
        self.q_table[row_diff, col_diff, action] += self.alpha * ( #aplha(학습률):새로운 정보가 기존 정보에 얼마나 반영될지를 조정하는 매개변수
            reward + self.gamma * self.q_table[next_row_diff, next_col_diff, next_action] #gamma(할인율): 미래 보상에 대한 현재 가치 평가를 나타냄
            - self.q_table[row_diff, col_diff, action] #현재 Q값
        )

    def train(self, num_episodes=1000): #에이전트를 환경에서 훈련시키는 함수
        for episode in range(num_episodes):
            state = self.env.reset()  #초기화
            action = self.choose_action(state)  # 탐욕정책에 따라 행동

            done = False
            while not done:  # 에이전트가 목표점에 도달했거나, 종료 조건을 만족하면 done = True가 되어 while 루프가 종료
                next_state, reward, done = self.env.step(action)  # 에이전트가 현재 선택한 행동(action)을 환경에 적용,다음 상태(next_state), 보상(reward), 그리고 종료 여부(done)를 반환
                next_action = self.choose_action(next_state)  # 탐욕정책으로 다음 행동 결정

                # Q테이블 업데이트
                self.update_q_table(state, action, reward, next_state, next_action) #값 업데이트

                state = next_state #값 업데이트
                action = next_action #값 업데이트

            print(f"Episode {episode + 1}/{num_episodes} finished.")

# 실행
env = GridWorldEnvironment(start_point=(0, 0), end_point=(4, 4), gridworld_size=(5, 5))
agent = SarsaAgent(env)
agent.train(num_episodes=500)
# Out:
# Episode 1/500 finished.
# Episode 2/500 finished.
# Episode 3/500 finished.
# Episode 4/500 finished.
# Episode 5/500 finished.
# Episode 6/500 finished.
# Episode 7/500 finished.
# Episode 8/500 finished.
# Episode 9/500 finished.
# Episode 10/500 finished.
# Episode 11/500 finished.
# Episode 12/500 finished.
# Episode 13/500 finished.
# Episode 14/500 finished.
# Episode 15/500 finished.
# Episode 16/500 finished.
# Episode 17/500 finished.
# Episode 18/500 finished.
# Episode 19/500 finished.
# Episode 20/500 finished.
# Episode 21/500 finished.
# Episode 22/500 finished.
# Episode 23/500 finished.
# Episode 24/500 finished.
# Episode 25/500 finished.
# Episode 26/500 finished.
# Episode 27/500 finished.
# Episode 28/500 finished.
# Episode 29/500 finished.
# Episode 30/500 finished.
# Episode 31/500 finished.
# Episode 32/500 finished.
# Episode 33/500 finished.
# Episode 34/500 finished.
# Episode 35/500 finished.
# Episode 36/500 finished.
# Episode 37/500 finished.
# Episode 38/500 finished.
# Episode 39/500 finished.
# Episode 40/500 finished.
# Episode 41/500 finished.
# Episode 42/500 finished.
# Episode 43/500 finished.
# Episode 44/500 finished.
# Episode 45/500 finished.
# Episode 46/500 finished.
# Episode 47/500 finished.
# Episode 48/500 finished.
# Episode 49/500 finished.
# Episode 50/500 finished.
# Episode 51/500 finished.
# Episode 52/500 finished.
# Episode 53/500 finished.
# Episode 54/500 finished.
# Episode 55/500 finished.
# Episode 56/500 finished.
# Episode 57/500 finished.
# Episode 58/500 finished.
# Episode 59/500 finished.
# Episode 60/500 finished.
# Episode 61/500 finished.
# Episode 62/500 finished.
# Episode 63/500 finished.
# Episode 64/500 finished.
# Episode 65/500 finished.
# Episode 66/500 finished.
# Episode 67/500 finished.
# Episode 68/500 finished.
# Episode 69/500 finished.
# Episode 70/500 finished.
# Episode 71/500 finished.
# Episode 72/500 finished.
# Episode 73/500 finished.
# Episode 74/500 finished.
# Episode 75/500 finished.
# Episode 76/500 finished.
# Episode 77/500 finished.
# Episode 78/500 finished.
# Episode 79/500 finished.
# Episode 80/500 finished.
# Episode 81/500 finished.
# Episode 82/500 finished.
# Episode 83/500 finished.
# Episode 84/500 finished.
# Episode 85/500 finished.
# Episode 86/500 finished.
# Episode 87/500 finished.
# Episode 88/500 finished.
# Episode 89/500 finished.
# Episode 90/500 finished.
# Episode 91/500 finished.
# Episode 92/500 finished.
# Episode 93/500 finished.
# Episode 94/500 finished.
# Episode 95/500 finished.
# Episode 96/500 finished.
# Episode 97/500 finished.
# Episode 98/500 finished.
# Episode 99/500 finished.
# Episode 100/500 finished.
# Episode 101/500 finished.
# Episode 102/500 finished.
# Episode 103/500 finished.
# Episode 104/500 finished.
# Episode 105/500 finished.
# Episode 106/500 finished.
# Episode 107/500 finished.
# Episode 108/500 finished.
# Episode 109/500 finished.
# Episode 110/500 finished.
# Episode 111/500 finished.
# Episode 112/500 finished.
# Episode 113/500 finished.
# Episode 114/500 finished.
# Episode 115/500 finished.
# Episode 116/500 finished.
# Episode 117/500 finished.
# Episode 118/500 finished.
# Episode 119/500 finished.
# Episode 120/500 finished.
# Episode 121/500 finished.
# Episode 122/500 finished.
# Episode 123/500 finished.
# Episode 124/500 finished.
# Episode 125/500 finished.
# Episode 126/500 finished.
# Episode 127/500 finished.
# Episode 128/500 finished.
# Episode 129/500 finished.
# Episode 130/500 finished.
# Episode 131/500 finished.
# Episode 132/500 finished.
# Episode 133/500 finished.
# Episode 134/500 finished.
# Episode 135/500 finished.
# Episode 136/500 finished.
# Episode 137/500 finished.
# Episode 138/500 finished.
# Episode 139/500 finished.
# Episode 140/500 finished.
# Episode 141/500 finished.
# Episode 142/500 finished.
# Episode 143/500 finished.
# Episode 144/500 finished.
# Episode 145/500 finished.
# Episode 146/500 finished.
# Episode 147/500 finished.
# Episode 148/500 finished.
# Episode 149/500 finished.
# Episode 150/500 finished.
# Episode 151/500 finished.
# Episode 152/500 finished.
# Episode 153/500 finished.
# Episode 154/500 finished.
# Episode 155/500 finished.
# Episode 156/500 finished.
# Episode 157/500 finished.
# Episode 158/500 finished.
# Episode 159/500 finished.
# Episode 160/500 finished.
# Episode 161/500 finished.
# Episode 162/500 finished.
# Episode 163/500 finished.
# Episode 164/500 finished.
# Episode 165/500 finished.
# Episode 166/500 finished.
# Episode 167/500 finished.
# Episode 168/500 finished.
# Episode 169/500 finished.
# Episode 170/500 finished.
# Episode 171/500 finished.
# Episode 172/500 finished.
# Episode 173/500 finished.
# Episode 174/500 finished.
# Episode 175/500 finished.
# Episode 176/500 finished.
# Episode 177/500 finished.
# Episode 178/500 finished.
# Episode 179/500 finished.
# Episode 180/500 finished.
# Episode 181/500 finished.
# Episode 182/500 finished.
# Episode 183/500 finished.
# Episode 184/500 finished.
# Episode 185/500 finished.
# Episode 186/500 finished.
# Episode 187/500 finished.
# Episode 188/500 finished.
# Episode 189/500 finished.
# Episode 190/500 finished.
# Episode 191/500 finished.
# Episode 192/500 finished.
# Episode 193/500 finished.
# Episode 194/500 finished.
# Episode 195/500 finished.
# Episode 196/500 finished.
# Episode 197/500 finished.
# Episode 198/500 finished.
# Episode 199/500 finished.
# Episode 200/500 finished.
# Episode 201/500 finished.
# Episode 202/500 finished.
# Episode 203/500 finished.
# Episode 204/500 finished.
# Episode 205/500 finished.
# Episode 206/500 finished.
# Episode 207/500 finished.
# Episode 208/500 finished.
# Episode 209/500 finished.
# Episode 210/500 finished.
# Episode 211/500 finished.
# Episode 212/500 finished.
# Episode 213/500 finished.
# Episode 214/500 finished.
# Episode 215/500 finished.
# Episode 216/500 finished.
# Episode 217/500 finished.
# Episode 218/500 finished.
# Episode 219/500 finished.
# Episode 220/500 finished.
# Episode 221/500 finished.
# Episode 222/500 finished.
# Episode 223/500 finished.
# Episode 224/500 finished.
# Episode 225/500 finished.
# Episode 226/500 finished.
# Episode 227/500 finished.
# Episode 228/500 finished.
# Episode 229/500 finished.
# Episode 230/500 finished.
# Episode 231/500 finished.
# Episode 232/500 finished.
# Episode 233/500 finished.
# Episode 234/500 finished.
# Episode 235/500 finished.
# Episode 236/500 finished.
# Episode 237/500 finished.
# Episode 238/500 finished.
# Episode 239/500 finished.
# Episode 240/500 finished.
# Episode 241/500 finished.
# Episode 242/500 finished.
# Episode 243/500 finished.
# Episode 244/500 finished.
# Episode 245/500 finished.
# Episode 246/500 finished.
# Episode 247/500 finished.
# Episode 248/500 finished.
# Episode 249/500 finished.
# Episode 250/500 finished.
# Episode 251/500 finished.
# Episode 252/500 finished.
# Episode 253/500 finished.
# Episode 254/500 finished.
# Episode 255/500 finished.
# Episode 256/500 finished.
# Episode 257/500 finished.
# Episode 258/500 finished.
# Episode 259/500 finished.
# Episode 260/500 finished.
# Episode 261/500 finished.
# Episode 262/500 finished.
# Episode 263/500 finished.
# Episode 264/500 finished.
# Episode 265/500 finished.
# Episode 266/500 finished.
# Episode 267/500 finished.
# Episode 268/500 finished.
# Episode 269/500 finished.
# Episode 270/500 finished.
# Episode 271/500 finished.
# Episode 272/500 finished.
# Episode 273/500 finished.
# Episode 274/500 finished.
# Episode 275/500 finished.
# Episode 276/500 finished.
# Episode 277/500 finished.
# Episode 278/500 finished.
# Episode 279/500 finished.
# Episode 280/500 finished.
# Episode 281/500 finished.
# Episode 282/500 finished.
# Episode 283/500 finished.
# Episode 284/500 finished.
# Episode 285/500 finished.
# Episode 286/500 finished.
# Episode 287/500 finished.
# Episode 288/500 finished.
# Episode 289/500 finished.
# Episode 290/500 finished.
# Episode 291/500 finished.
# Episode 292/500 finished.
# Episode 293/500 finished.
# Episode 294/500 finished.
# Episode 295/500 finished.
# Episode 296/500 finished.
# Episode 297/500 finished.
# Episode 298/500 finished.
# Episode 299/500 finished.
# Episode 300/500 finished.
# Episode 301/500 finished.
# Episode 302/500 finished.
# Episode 303/500 finished.
# Episode 304/500 finished.
# Episode 305/500 finished.
# Episode 306/500 finished.
# Episode 307/500 finished.
# Episode 308/500 finished.
# Episode 309/500 finished.
# Episode 310/500 finished.
# Episode 311/500 finished.
# Episode 312/500 finished.
# Episode 313/500 finished.
# Episode 314/500 finished.
# Episode 315/500 finished.
# Episode 316/500 finished.
# Episode 317/500 finished.
# Episode 318/500 finished.
# Episode 319/500 finished.
# Episode 320/500 finished.
# Episode 321/500 finished.
# Episode 322/500 finished.
# Episode 323/500 finished.
# Episode 324/500 finished.
# Episode 325/500 finished.
# Episode 326/500 finished.
# Episode 327/500 finished.
# Episode 328/500 finished.
# Episode 329/500 finished.
# Episode 330/500 finished.
# Episode 331/500 finished.
# Episode 332/500 finished.
# Episode 333/500 finished.
# Episode 334/500 finished.
# Episode 335/500 finished.
# Episode 336/500 finished.
# Episode 337/500 finished.
# Episode 338/500 finished.
# Episode 339/500 finished.
# Episode 340/500 finished.
# Episode 341/500 finished.
# Episode 342/500 finished.
# Episode 343/500 finished.
# Episode 344/500 finished.
# Episode 345/500 finished.
# Episode 346/500 finished.
# Episode 347/500 finished.
# Episode 348/500 finished.
# Episode 349/500 finished.
# Episode 350/500 finished.
# Episode 351/500 finished.
# Episode 352/500 finished.
# Episode 353/500 finished.
# Episode 354/500 finished.
# Episode 355/500 finished.
# Episode 356/500 finished.
# Episode 357/500 finished.
# Episode 358/500 finished.
# Episode 359/500 finished.
# Episode 360/500 finished.
# Episode 361/500 finished.
# Episode 362/500 finished.
# Episode 363/500 finished.
# Episode 364/500 finished.
# Episode 365/500 finished.
# Episode 366/500 finished.
# Episode 367/500 finished.
# Episode 368/500 finished.
# Episode 369/500 finished.
# Episode 370/500 finished.
# Episode 371/500 finished.
# Episode 372/500 finished.
# Episode 373/500 finished.
# Episode 374/500 finished.
# Episode 375/500 finished.
# Episode 376/500 finished.
# Episode 377/500 finished.
# Episode 378/500 finished.
# Episode 379/500 finished.
# Episode 380/500 finished.
# Episode 381/500 finished.
# Episode 382/500 finished.
# Episode 383/500 finished.
# Episode 384/500 finished.
# Episode 385/500 finished.
# Episode 386/500 finished.
# Episode 387/500 finished.
# Episode 388/500 finished.
# Episode 389/500 finished.
# Episode 390/500 finished.
# Episode 391/500 finished.
# Episode 392/500 finished.
# Episode 393/500 finished.
# Episode 394/500 finished.
# Episode 395/500 finished.
# Episode 396/500 finished.
# Episode 397/500 finished.
# Episode 398/500 finished.
# Episode 399/500 finished.
# Episode 400/500 finished.
# Episode 401/500 finished.
# Episode 402/500 finished.
# Episode 403/500 finished.
# Episode 404/500 finished.
# Episode 405/500 finished.
# Episode 406/500 finished.
# Episode 407/500 finished.
# Episode 408/500 finished.
# Episode 409/500 finished.
# Episode 410/500 finished.
# Episode 411/500 finished.
# Episode 412/500 finished.
# Episode 413/500 finished.
# Episode 414/500 finished.
# Episode 415/500 finished.
# Episode 416/500 finished.
# Episode 417/500 finished.
# Episode 418/500 finished.
# Episode 419/500 finished.
# Episode 420/500 finished.
# Episode 421/500 finished.
# Episode 422/500 finished.
# Episode 423/500 finished.
# Episode 424/500 finished.
# Episode 425/500 finished.
# Episode 426/500 finished.
# Episode 427/500 finished.
# Episode 428/500 finished.
# Episode 429/500 finished.
# Episode 430/500 finished.
# Episode 431/500 finished.
# Episode 432/500 finished.
# Episode 433/500 finished.
# Episode 434/500 finished.
# Episode 435/500 finished.
# Episode 436/500 finished.
# Episode 437/500 finished.
# Episode 438/500 finished.
# Episode 439/500 finished.
# Episode 440/500 finished.
# Episode 441/500 finished.
# Episode 442/500 finished.
# Episode 443/500 finished.
# Episode 444/500 finished.
# Episode 445/500 finished.
# Episode 446/500 finished.
# Episode 447/500 finished.
# Episode 448/500 finished.
# Episode 449/500 finished.
# Episode 450/500 finished.
# Episode 451/500 finished.
# Episode 452/500 finished.
# Episode 453/500 finished.
# Episode 454/500 finished.
# Episode 455/500 finished.
# Episode 456/500 finished.
# Episode 457/500 finished.
# Episode 458/500 finished.
# Episode 459/500 finished.
# Episode 460/500 finished.
# Episode 461/500 finished.
# Episode 462/500 finished.
# Episode 463/500 finished.
# Episode 464/500 finished.
# Episode 465/500 finished.
# Episode 466/500 finished.
# Episode 467/500 finished.
# Episode 468/500 finished.
# Episode 469/500 finished.
# Episode 470/500 finished.
# Episode 471/500 finished.
# Episode 472/500 finished.
# Episode 473/500 finished.
# Episode 474/500 finished.
# Episode 475/500 finished.
# Episode 476/500 finished.
# Episode 477/500 finished.
# Episode 478/500 finished.
# Episode 479/500 finished.
# Episode 480/500 finished.
# Episode 481/500 finished.
# Episode 482/500 finished.
# Episode 483/500 finished.
# Episode 484/500 finished.
# Episode 485/500 finished.
# Episode 486/500 finished.
# Episode 487/500 finished.
# Episode 488/500 finished.
# Episode 489/500 finished.
# Episode 490/500 finished.
# Episode 491/500 finished.
# Episode 492/500 finished.
# Episode 493/500 finished.
# Episode 494/500 finished.
# Episode 495/500 finished.
# Episode 496/500 finished.
# Episode 497/500 finished.
# Episode 498/500 finished.
# Episode 499/500 finished.
# Episode 500/500 finished.

# %% [markdown]
# # Main

# %% [markdown]
# - **SARSA**를 이용해 그리드 월드 학습시키기
# - 학습 지표 시각화

# %%
env.render()
# Out:
# S X X X X
# . . . . X
# . . . . X
# . . . . X
# . . . . A

# %%
def visualize_optimal_path(env, agent): #학습이 끝난 후, 에이전트가 학습한 최적 경로를 시각화하는 함수
    state = env.reset()
    done = False
    env.render()  #처음 상태 출력

    while not done:
        action = np.argmax(agent.q_table[state[0], state[1]])  # 최적의 행동 찾기
        next_state, _, done = env.step(action)

        env.render()  # 각 스텝마다의 현 상태 출력
        state = next_state

# 실행
visualize_optimal_path(env, agent)
# Out:
# A . . . .
# . . . . .
# . . . . .
# . . . . .
# . . . . G
#
# S A . . .
# . . . . .
# . . . . .
# . . . . .
# . . . . G
#
# S X A . .
# . . . . .
# . . . . .
# . . . . .
# . . . . G
#
# S X X A .
# . . . . .
# . . . . .
# . . . . .
# . . . . G
#
# S X X X A
# . . . . .
# . . . . .
# . . . . .
# . . . . G
#
# S X X X X
# . . . . A
# . . . . .
# . . . . .
# . . . . G
#
# S X X X X
# . . . . X
# . . . . A
# . . . . .
# . . . . G
#
# S X X X X
# . . . . X
# . . . . X
# . . . . A
# . . . . G
#
# S X X X X
# . . . . X
# . . . . X
# . . . . X
# . . . . A

# %% [markdown]
# SARSA 알고리즘의 흐름 요약
#
#
#
# 1.   환경 초기화 및 첫 행동 선택: 각 에피소드의 시작에서 에이전트는 환경을 초기화하고 탐욕 정책으로 첫 행동 선택
#
# 2.   상태 전이: 에이전트는 현재 행동을 수행하고, 그 결과로 다음 상태, 보상, 에피소드 종료 여부를 얻음
#
# 3. 다음 행동 선택: 에이전트는 다음 상태에서 탐욕정책으로 다음 행동을 선택
#
# 4. Q-테이블 업데이트: SARSA 업데이트 규칙에 따라 현재 상태-행동 쌍의 Q-값을 갱신
#
# 5. 상태 및 행동 업데이트: 에이전트는 다음 상태와 행동으로 전이하여, 에피소드가 끝날 때까지 과정을 반복
#
# 6. 에피소드 종료 후 출력: 에피소드가 끝나면 완료 메시지를 출력하고, 다음 에피소드로 넘어감
#
#
# 이 과정을 통해 SARSA 알고리즘은 매 에피소드마다 환경을 학습하고, 에이전트는 목표 지점에 도달할 확률이 점점 높아지도록 Q-값을 업데이트함
